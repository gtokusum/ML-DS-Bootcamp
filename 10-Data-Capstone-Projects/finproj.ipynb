# %%
from pandas_datareader import data, wb
import pandas as pd
import numpy as np
import datetime
import os
# %matplotlib inline

import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('whitegrid')
# %matplotlib inline

# Optional Plotly Method Imports
import plotly
import cufflinks as cf
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
start = datetime.datetime(2006,1,1)
end = datetime.datetime(2016,1,1)
# BAC = data.DataReader('BAC','yahoo',start = start,end=end)
BAC = data.DataReader('BAC','stooq',start=start,end=end)
C = data.DataReader('C','stooq',start,end)
GS = data.DataReader('GS','stooq',start,end)
JPM = data.DataReader('JPM','stooq',start,end)
MS = data.DataReader('MS','stooq',start,end)
WFC = data.DataReader('WFC','stooq',start,end)

# %%
start08 = datetime.datetime(2008,1,1)
end08 = datetime.datetime(2009,1,1)
BAC08 = data.DataReader('BAC','stooq',start08,end08)
plt.figure(figsize=(12,6))
BAC08['Close'].rolling(window=30).mean().plot(label='30 Day Avg')
BAC08['Close'].plot(label='BAC CLOSE')
plt.legend()
